# %%
# Basics 
a = []
b = [1,2,3]
c = ['A','B','C']

a = list()
b = list("ABC") #['A', 'B', 'C']
c = list([1,2,3,4]) #[1,2,3,4]
d = list((1,2,3,4)) #[1,2,3,4]
e = list({1,2,3,4}) #[1,2,3,4]

a = list(range(5)) #[0,1,2,3,4]
b = list(range(3,6)) #[3,4,5]
c = list(range(0,11,2)) #[0,2,4,6,8]

a = 1,2,3 #(1,2,3)
b = (1,2,3)#(1,2,3)
c = 'A','B','C' #(A,B,C)
d = tuple("ABC") #(A,B,C)
e = tuple([1,2,3])#(1,2,3)
f = tuple({1,2,3})#(1,2,3)
a = tuple(range(5)) #(0,1,2,3,4)
b = tuple(range(3,6)) #(3,4,5)
c = tuple(range(0,11,2)) #(0,2,4,6,8)

x = [1,2,3]
a,b,c = x 
a,b,c

x = [i for i in range(101)]
print(x[50::2])
print(x[-50:-20])

print(x[50],x[-50])
print(x[-20])

print(x[:10])
print(x[80:])
print(x[-21:])
print(x[::50])
print(x[::-50])

a,b = 1,2 
a,b = b,a
print(f"a = {a}")
print(f"b = {b}")
