# %%
class node:
    def __init__(self,number):
        self.number = number 
        self.next = None
        self.prev = None 
    def getData(self):
        return self.number 
    def getNext(self):
        return self.next

class DoublyLinkedList:
    def __init__(self,head,tail):
        self.head = head 
        self.tail = tail
    
    def 
    
        
    def __str__(self):
        outsring=""
        current=self.head
        while current!=None: 
            outsring+=str(current.getData())+"<->"
            current=current.getNext()
        return outsring
A=node(1)
B=node(2)
C=node(3)
D=node(4)
E=node(5)

F=node(0)
G=node(6)
H=node(7)
A.next=(B)
B.prev=(A)
B.next=(C)
C.prev=(B)
C.next=(D)
D.prev=(C)
D.next=(E)
E.prev=(D)
# Out:
# 0<->1<->7<->2<->3<->4<->5<->6<->

# %%
def findKthPosition(arr,k):
    newList=[]
    for i in range(1,arr[len(arr)-1]):
        newList.append(i)
    newList=set(newList)-set(arr)
    newList=list(newList)
    print(newList[k-1])

findKthPosition([2,3,4,7,11],5)
findKthPosition([1,2,3,4],2)
# Out:
# 9
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-28d0edacf8d3> in <module>
#       8
#       9 findKthPosition([2,3,4,7,11],5)
# ---> 10 findKthPosition([1,2,3,4],2)
#
# <ipython-input-14-28d0edacf8d3> in findKthPosition(arr, k)
#       5     newList=set(newList)-set(arr)
#       6     newList=list(newList)
# ----> 7     print(newList[k-1])
#       8
#       9 findKthPosition([2,3,4,7,11],5)
#
# IndexError: list index out of range
