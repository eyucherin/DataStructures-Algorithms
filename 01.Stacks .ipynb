# %%
##FIXED STACK 

from typing import Any

class Stack:
    class Empty(Exception):
        pass 
    class Full(Exception):
        pass
    
    
    def __init__(self,capacity:int):
        self.stk = [None] * capacity 
        self.ptr = 0 
        self.capacity = capacity 
    
    def __len__(self) -> int:
        return self.pointer
    
    def is_empty(self) -> bool:
        return self.ptr == 0 
    
    def is_full(self) ->bool:
        return self.ptr == self.capacity 
    
    def push(self,data:Any):
        if self.is_full():
            raise Stack.Full("The Stack is Full")
            
        self.stk[self.ptr] = data
        self.ptr += 1 
    
    def pop(self) -> Any: 
        if self.is_empty():
            raise Stack.Empty("The Stack is Empty")
        self.ptr -= 1 
        return self.stk[self.ptr]
    
    def peek(self) -> Any: 
        if self.is_empty():
            raise Stack.Empty("The Stack is Empty")
        return self.stk[self.ptr - 1]
    
    def clear(self):
        self.ptr = 0 
    
    def find(self, val:Any) -> Any: 
        if self.is_empty():
            raise Stack.Empty("The Stack is Empty")
        for i in range(self.ptr - 1, -1 , -1):
            if self.stk[self.ptr] == val:
                return i 
        return -1 
    
    def count(self,val:Any) -> int: 
        count = 0 
        for i in range(self.ptr):
            if self.stk[i] == val: 
                count += 1 
        return count 
    
    
    def __contains__(self,val:Any) -> bool: 
        return self.count(val)
    
    def dump(self) -> None: 
        if self.is_empty():
            raise Stack.Empty("The Stack is Empty")
        print(self.stk[:self.ptr])
# Out:
# [1]
# 2

# %%
## STACK 
from typing import Any
class Stack1: 
    class Empty(Exception):
        pass
    
    def __init__(self):
        self.stk = []
    
    def push(self,val:Any) -> None: 
        self.stk.append(val)
    
    def pop(self) -> Any:
        if len(self.stk) == 0:
            raise Stack1.Empty("The Stack is Empty")
        val = self.stk[-1]
        self.stk.pop()
        return val 
    
    def peek(self) -> Any: 
        return self.stk[-1]
    
    def __len__(self) -> int:
        return len(self.stk)
