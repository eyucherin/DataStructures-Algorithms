# %%
from typing import MutableSequence

def insertion_sort(a:MutableSequence) -> None: 
    n = len(a)
    
    for i in range(1,n):
        j = i 
        temp = a[i]
        
        while j>0 and a[j-1]>temp: 
            a[j] = a[j-1]
            j -= 1 
        a[j] = temp 
    print(a)
insertion_sort([5,4,3,1,0])
# Out:
# [0, 1, 3, 4, 5]

# %% [markdown]
# #####
