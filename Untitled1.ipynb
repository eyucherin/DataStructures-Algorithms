# %%
a = [1,2,3,4,5]
b = list(map(lambda x: x+1,a))
c = list(map(lambda x: x*2,a))
d = list(map(lambda x: str(x),a))
print(a)
print(b)
print(c)
print(d)
# Out:
# [1, 2, 3, 4, 5]
# [2, 3, 4, 5, 6]
# [2, 4, 6, 8, 10]
# ['1', '2', '3', '4', '5']

# %%
a = [1,2,3,4,5,6]
b = list(filter(lambda x: x%2 == 0,a))
c = list(map(lambda x: x*2,b))
print(a)
print(b)#[2, 4, 6]
print(c)
print(d)
# Out:
# [1, 2, 3, 4, 5, 6]
# [2, 4, 6]
# [4, 8, 12]
# [<filter object at 0x1065f6df0>, <filter object at 0x1065f6820>, <filter object at 0x1065f6520>, <filter object at 0x1065f6ca0>, <filter object at 0x1065f6b50>, <filter object at 0x1065f66a0>]
