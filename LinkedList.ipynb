# %%
class Node: 
    def __init__(self, data = None):
        self.data = data 
        self.next = None 

class SLinkedList: 
    def __init__(self,head = None):
        self.head = head 
        
    def getFirst(self):
        return self.head
    
    def getLast(self):
        current = self.head 
        while current.next != None : 
            current = current.next
        return current 
        
    def append(self,newVal):
        current = self.head
        while current.next != None: 
            current = current.next 
        current.next = newVal
        
    def appendAll(self,newLinkedList):
        current = self.head 
        newCurrent = newLinkedList.head
        while current.next!= None: 
            current = current.next
        current.next = newCurrent
        while newCurrent:
            current = newCurrent.next
            newCurrent = newCurrent.next
        
    def add(self,indexVal,newVal):
        current = self.head 
        prev = None 
        count = indexVal 
        while current.next != None and count!= 0 : 
            prev = current 
            current = current.next 
            count -= 1 
        prev.next = newVal 
        newVal.next = current
    
    def deleteNode(self,node):
        current = self.head 
        prevNode = None 
        nextNode = None 
        
        while current == node.datat
        

    def __str__(self):
        current = self.head 
        answer = ""
        while current: 
            answer += str(current.data)+ "->"
            current = current.next 
        return answer
    

if __name__ == '__main__':
    a = Node(1)
    b = Node(2)
    c = Node(3)
    d = Node(4)
    e = Node(3.5)
    A = SLinkedList(a)
    
    A.append(b)
    A.append(c)
    A.append(d)
    A.add(3,e)
    print(A)

    
    a1 = Node(1.1)
    a2 = Node(1.2)
    a3 = Node(1.3)
    a4 = Node(1.4)
    a5 = Node(1.5)
    
    A1 = SLinkedList(a1)
    A1.append(a2)
    A1.append(a3)
    A1.append(a4)
    A1.append(a5)
    print(A1)
    
    A.appendAll(A1)
    print(A)
# Out:
# 1->2->3->3.5->4->
# 1.1->1.2->1.3->1.4->1.5->
# 1->2->3->3.5->4->1.1->1.2->1.3->1.4->1.5->
